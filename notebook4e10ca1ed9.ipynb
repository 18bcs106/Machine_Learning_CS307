# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mu,sigma=5,1
x = np.random.normal(mu,sigma,10)
np.mean(x)
# Out:
# 4.854317214947419

# %%
y = 1/(np.sqrt(2*np.pi*sigma**2)) * np.exp(-0.5*((x-mu)/sigma)**2)
y
# Out:
# array([0.07761787, 0.38425744, 0.39483276, 0.08150056, 0.35670432,
#        0.36791454, 0.33969781, 0.05798901, 0.34891304, 0.03543522])

# %%
a = sns.scatterplot(x,y,color='green')
a = sns.lineplot(x,y,color='green')
#a = sns.distplot(x,hist = False)
a.set_title("Distrution")
a.lines[0].set_linestyle("--")
a.set_xlim(0,10)

        
plt.savefig("guassian.png")
# Out:
# /home/dcodek/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/dcodek/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig,axes = plt.subplots(3,4,figsize=(13,10))
z=0
for i in range(3):
    for j in range(4):
        if z>10:
            break
        tmp=1/(np.sqrt(2*np.pi)) * np.exp(-0.5*((x-z))**2)
        sns.scatterplot(x,y,ax=axes[i,j])
        axes[i,j].set_xlabel("μ = "+str(z))
        axes[i,j].set_xlim(0,10)
        sns.scatterplot(x,tmp,ax=axes[i,j],color="red")
        sns.lineplot(x,tmp,ax=axes[i,j],color="red")
        z=z+1
        
plt.savefig("plot.png")
# Out:
# /home/dcodek/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/dcodek/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/dcodek/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...
